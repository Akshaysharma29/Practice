# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('8f86dc50-7-dataset/train.csv')

# %%
df.head()
# Out:
#         ID         DateTime  TempOut  HiTemp  LowTemp  OutHum  DewPt  \
# 0  PR00001  07-12-2040 0:15     53.5    53.6     53.5      85   49.1
# 1  PR00002  07-12-2040 0:30     53.5    53.5     53.4      85   49.1
# 2  PR00003  07-12-2040 0:45     53.3    53.5     53.2      85   48.9
# 3  PR00004  07-12-2040 1:00     53.1    53.3     53.0      86   49.0
# 4  PR00005  07-12-2040 1:15     52.9    53.1     52.9      86   48.8
#
#    WindSpeed WindDir  WindRun ...  WindTx ISSRecpt  ArcInt  PA  PB  PC  PD  \
# 0          2     SSE      0.5 ...       1    100.0      15   1   1   1   1
# 1          2     SSE      0.5 ...       1    100.0      15   1   1   1   1
# 2          2     SSE      0.5 ...       1    100.0      15   1   1   1   1
# 3          2       S      0.5 ...       1    100.0      15   1   1   1   1
# 4          2       S      0.5 ...       1    100.0      15   1   1   1   1
#
#    PE  PF  PG
# 0   1   1   1
# 1   1   1   1
# 2   1   1   1
# 3   1   1   1
# 4   1   1   1
#
# ...

# %%
print(type(df['DateTime'].values))
x=df['DateTime'].values
y=df['PA'].values
# Out:
# <class 'numpy.ndarray'>

# %%
print(len(x))
print(type(x))
# Out:
# 40000
# <class 'numpy.ndarray'>

# %%
print(x[0][6:10])
# Out:
# 2040

# %%
x1 = []
print(int(x[0].split('-')[2].split(' ')[0]))
# x1.append(x[0].split('-')[2].split(' ')[0])
# print(x1)
c=0
for i in range(0,40000):
#     print(x[i][6:])
    c+=1
    x1.append(x[i][6:10])
# Out:
# 2040

# %%
print(c)
# print(x[5])
# Out:
# 40000

# %%
print(x1)
# Out:
# ['2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040', '2040
# ...

# %%
plt.scatter(x1,y)
plt.ylabel('Number')
plt.xlabel('DateTime')
plt.show()

# %%
plt.plot(x1[:20],y[:20],linewidth=2.0)
plt.ylabel('Number')
plt.xlabel('DateTime')
plt.show()

# %% [markdown]
# # The data is too inconsistent acc. to my understanding at this moment of time
